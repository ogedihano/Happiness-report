# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data2015 = pd.read_csv("2015.csv")
print(data2015.shape)
data2015.head()
# Out:
# (158, 12)
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
data2016 = pd.read_csv("2016.csv")
print(data2016.shape)
data2016.head()
# Out:
# (157, 13)
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
data2017 = pd.read_csv("2017.csv")
print(data2017.shape)
data2017.head()
# Out:
# (155, 12)
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
data2018 = pd.read_csv("2018.csv")
print(data2018.shape)
data2018.head()
# Out:
# (156, 9)
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
data2019 = pd.read_csv("2019.csv")
print(data2019.shape)
data2019.head()
# Out:
# (156, 9)
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ## 2015 and 2016

# %%
drop15 = ['Standard Error', 'Dystopia Residual']

# %%
drop16 = ['Upper Confidence Interval', 'Lower Confidence Interval', 'Dystopia Residual']

# %%
data2015.drop(drop15, axis = 1, inplace = True)
data2016.drop(drop16, axis = 1, inplace = True)

# %%
data2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
data2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
new_col = {'Happiness Rank':'rank', 'Happiness Score': 'score',
                     'Economy (GDP per Capita)': 'GDP_per_capita', 'Health (Life Expectancy)': 'life_expectancy',
                     'Trust (Government Corruption)': 'gov_trust'}

# %%
data2015.rename(columns = new_col, inplace = True)

# %%
data2016.rename(columns = new_col, inplace = True)

# %%
data2015.columns == data2016.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
data2015.columns = data2015.columns.str.lower()
data2016.columns = data2016.columns.str.lower()
data2015.columns == data2016.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# ## 2017

# %%
data2017.drop(['Whisker.high','Whisker.low','Dystopia.Residual'], axis = 1, inplace = True)

# %%
data2017.shape
# Out:
# (155, 9)

# %%
data2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score',
#        'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
#        'Freedom', 'Generosity', 'Trust..Government.Corruption.'],
#       dtype='object')

# %%
new_col17 = {'Happiness.Rank':'rank', 'Happiness.Score': 'score',
                     'Economy..GDP.per.Capita.': 'GDP_per_capita', 'Health..Life.Expectancy.': 'life_expectancy',
                     'Trust..Government.Corruption.': 'gov_trust'}

# %%
data2017.rename(columns = new_col17, inplace = True)

# %%
data2017.shape
# Out:
# (155, 9)

# %%
data2017.columns
# Out:
# Index(['Country', 'rank', 'score', 'GDP_per_capita', 'Family',
#        'life_expectancy', 'Freedom', 'Generosity', 'gov_trust'],
#       dtype='object')

# %%
data2017.columns = data2017.columns.str.lower()

# %%
for i in data2017.columns:
    print(i in data2016.columns, i)
#all columns are now in 2016 columns. 1 missing is region
# Out:
# True country
# True rank
# True score
# True gdp_per_capita
# True family
# True life_expectancy
# True freedom
# True generosity
# True gov_trust

# %% [markdown]
# ## 2018 and 2019

# %%
data2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
data2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
new_col1819 = {'Overall rank':'rank','Country or region':'country',
                     'GDP per capita': 'GDP_per_capita', 'Freedom to make life choices':'freedom',
                      'Healthy life expectancy': 'life_expectancy',
                     'Perceptions of corruption': 'gov_trust', 'Social support':'family'}

# %%
data2018.rename(columns = new_col1819, inplace=  True)

# %%
data2019.rename(columns = new_col1819, inplace = True)

# %%
data2018.columns = data2018.columns.str.lower()
data2019.columns = data2019.columns.str.lower()
data2018.columns == data2019.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
data2019.columns
# Out:
# Index(['rank', 'country', 'score', 'gdp_per_capita', 'family',
#        'life_expectancy', 'freedom', 'generosity', 'gov_trust'],
#       dtype='object')

# %%
#check if all 2018,2019 columns in 2015,2016

for i in data2018.columns:
    print(i in data2016.columns, i)
# Out:
# True rank
# True country
# True score
# True gdp_per_capita
# True family
# True life_expectancy
# True freedom
# True generosity
# True gov_trust

# %% [markdown]
# #### SINCE ALL COLUMNS IN OUR DATASETS ARE NOW THE SAME, WE CAN MAP REGION TO COUNTRY
# from the 2015 and 2016 data

# %%
empty_dict = {}
for country, region in zip(data2015['country'],data2015['region']):
    empty_dict[country] = region
for country, region in zip(data2016['country'],data2016['region']):
    empty_dict[country] = region

# %%
data2017['region'] = data2017['country'].map(empty_dict)
data2018['region'] = data2018['country'].map(empty_dict)
data2019['region'] = data2019['country'].map(empty_dict)

# %%
### inserting year column to know where the data is from
data2015['year'] = 2015
data2016['year'] = 2016
data2017['year'] = 2017
data2018['year'] = 2018
data2019['year'] = 2019

# %%
columnlis = []
columnlis.append([data2015.columns.values,data2016.columns.values,
                  data2017.columns.values,data2018.columns.values,
                  data2019.columns.values])

# %%
data2015.shape, data2016.shape, data2017.shape, data2018.shape, data2019.shape
# Out:
# ((158, 11), (157, 11), (155, 11), (156, 11), (156, 11))

# %%
np.unique(columnlis)
# Out:
# array(['country', 'family', 'freedom', 'gdp_per_capita', 'generosity',
#        'gov_trust', 'life_expectancy', 'rank', 'region', 'score', 'year'],
#       dtype=object)

# %% [markdown]
# ### merging all datasets together

# %%
df = pd.concat([data2015,data2016,data2017,data2018,data2019], axis = 0, ignore_index = True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          782 non-null    object
#  1   region           774 non-null    object
#  2   rank             782 non-null    int64
#  3   score            782 non-null    float64
#  4   gdp_per_capita   782 non-null    float64
#  5   family           782 non-null    float64
#  6   life_expectancy  782 non-null    float64
#  7   freedom          782 non-null    float64
#  8   gov_trust        781 non-null    float64
#  9   generosity       782 non-null    float64
#  10  year             782 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 67.3+ KB
#        country          region  rank  score  gdp_per_capita   family  \
# 0  Switzerland  Western Europe     1  7.587         1.39651  1.34951
# 1      Iceland  Western Europe     2  7.561         1.30232  1.40223
# 2      Denmark  Western Europe     3  7.527         1.32548  1.36058
# 3       Norway  Western Europe     4  7.522         1.45900  1.33095
# 4       Canada   North America     5  7.427         1.32629  1.32261
#
#    life_expectancy  freedom  gov_trust  generosity  year
# 0          0.94143  0.66557    0.41978     0.29678  2015
# 1          0.94784  0.62877    0.14145     0.43630  2015
# 2          0.87464  0.64938    0.48357     0.34139  2015
# 3          0.88521  0.66973    0.36503     0.34699  2015
# 4          0.90563  0.63297    0.32957     0.45811  2015

# %% [markdown]
# ##### filling in govt_trust
#
# gov_trust is missing a row in the year 2018

# %%
df[df['gov_trust'].isnull()]
# Out:
#                   country                           region  rank  score  \
# 489  United Arab Emirates  Middle East and Northern Africa    20  6.774
#
#      gdp_per_capita  family  life_expectancy  freedom  gov_trust  generosity  \
# 489           2.096   0.776             0.67    0.284        NaN       0.186
#
#      year
# 489  2018

# %% [markdown]
# The missing data is from UAE in year 2018

# %%
df.loc[df['country'] == 'United Arab Emirates', 'gov_trust'] = df.loc[df['country'] == 'United Arab Emirates', 'gov_trust'].fillna(df.loc[df['country'] == 'United Arab Emirates', 'gov_trust'].mean())

# %%
df.loc[df['country'] == 'United Arab Emirates', 'gov_trust']
# Out:
# 19     0.385830
# 185    0.355610
# 335    0.324490
# 489    0.311982
# 646    0.182000
# Name: gov_trust, dtype: float64

# %% [markdown]
# ##### filling in missing regions

# %%
df[df['region'].isnull()]

# most of the missing regions are due to spelling error or misnaming, manual imputation will do
# Out:
#                       country region  rank  score  gdp_per_capita    family  \
# 347  Taiwan Province of China    NaN    33  6.422        1.433627  1.384565
# 385   Hong Kong S.A.R., China    NaN    71  5.472        1.551675  1.262791
# 507         Trinidad & Tobago    NaN    38  6.192        1.223000  1.492000
# 527           Northern Cyprus    NaN    58  5.835        1.229000  1.211000
# 664         Trinidad & Tobago    NaN    39  6.192        1.231000  1.477000
# 689           Northern Cyprus    NaN    64  5.718        1.263000  1.252000
# 709           North Macedonia    NaN    84  5.274        0.983000  1.294000
# 745                    Gambia    NaN   120  4.516        0.308000  0.939000
#
#      life_expectancy   freedom  gov_trust  generosity  year
# 347         0.793984  0.361467   0.063829    0.258360  2017
# 385         0.943062  0.490969   0.293934    0.374466  2017
# 507         0.564000  0.575000   0.019000    0.171000  2018
# 527         0.909000  0.495000   0.154000    0.179000  2018
# 664         0.713000  0.489000   0.016000    0.185000  2019
# 689         1.042000  0.417000   0.162000    0.191000  2019
# 709         0.838000  0.345000   0.034000    0.185000  2019
# 745         0.428000  0.382000   0.167000    0.269000  2019

# %%
df[df['country'] == 'Taiwan']
# Out:
#     country        region  rank  score  gdp_per_capita   family  \
# 37   Taiwan  Eastern Asia    38  6.298         1.29098  1.07617
# 192  Taiwan  Eastern Asia    34  6.379         1.39729  0.92624
# 495  Taiwan  Eastern Asia    26  6.441         1.36500  1.43600
# 650  Taiwan  Eastern Asia    25  6.446         1.36800  1.43000
#
#      life_expectancy  freedom  gov_trust  generosity  year
# 37           0.87530  0.39740    0.08129     0.25376  2015
# 192          0.79565  0.32377    0.06630     0.25495  2016
# 495          0.85700  0.41800    0.07800     0.15100  2018
# 650          0.91400  0.35100    0.09700     0.24200  2019

# %%
df[df['country']=='Hong Kong']
# Out:
#        country        region  rank  score  gdp_per_capita   family  \
# 71   Hong Kong  Eastern Asia    72  5.474         1.38604  1.05818
# 232  Hong Kong  Eastern Asia    75  5.458         1.51070  0.87021
# 545  Hong Kong  Eastern Asia    76  5.430         1.40500  1.29000
# 701  Hong Kong  Eastern Asia    76  5.430         1.43800  1.27700
#
#      life_expectancy  freedom  gov_trust  generosity  year
# 71           1.01328  0.59608    0.37124     0.39478  2015
# 232          0.95277  0.48079    0.31647     0.40097  2016
# 545          1.03000  0.52400    0.29100     0.24600  2018
# 701          1.12200  0.44000    0.28700     0.25800  2019

# %% [markdown]
# ##### Taiwan and Hong Kong are due to error in naming, I will change it manually

# %%
#Taiwan
df.loc[347,'country'] = 'Taiwan'
df.loc[347,'region'] = 'Eastern Asia'

#Hongkong
df.loc[385,'country'] = 'Hong Kong'
df.loc[385,'region'] = 'Eastern Asia'

# %%
df.loc[df['region'].isnull(), 'country']
# Out:
# 507    Trinidad & Tobago
# 527      Northern Cyprus
# 664    Trinidad & Tobago
# 689      Northern Cyprus
# 709      North Macedonia
# 745               Gambia
# Name: country, dtype: object

# %%
df['region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia', nan], dtype=object)

# %%
df[df['country'].str.contains('Trinidad')]
# Out:
#                  country                       region  rank  score  \
# 40   Trinidad and Tobago  Latin America and Caribbean    41  6.168
# 200  Trinidad and Tobago  Latin America and Caribbean    43  6.168
# 352  Trinidad and Tobago  Latin America and Caribbean    38  6.168
# 507    Trinidad & Tobago                          NaN    38  6.192
# 664    Trinidad & Tobago                          NaN    39  6.192
#
#      gdp_per_capita    family  life_expectancy   freedom  gov_trust  \
# 40         1.211830  1.183540         0.614830  0.558840   0.011400
# 200        1.325720  0.985690         0.526080  0.484530   0.012410
# 352        1.361356  1.380229         0.519983  0.518631   0.008965
# 507        1.223000  1.492000         0.564000  0.575000   0.019000
# 664        1.231000  1.477000         0.713000  0.489000   0.016000
#
#      generosity  year
# 40     0.318440  2015
# 200    0.319350  2016
# 352    0.325296  2017
# 507    0.171000  2018
# 664    0.185000  2019

# %%
#manullay change
df.loc[[507, 664],'country'] = 'Trinidad and Tobago'
df.loc[[507, 664],'region'] = 'Latin America and Caribbean'

# %%
df[df['country'] == 'Macedonia']
# Out:
#        country                      region  rank  score  gdp_per_capita  \
# 92   Macedonia  Central and Eastern Europe    93  5.007        0.918510
# 252  Macedonia  Central and Eastern Europe    95  5.121        1.019300
# 406  Macedonia  Central and Eastern Europe    92  5.175        1.064578
# 558  Macedonia  Central and Eastern Europe    89  5.185        0.959000
#
#        family  life_expectancy   freedom  gov_trust  generosity  year
# 92   1.002320         0.735450  0.334570   0.053270    0.223590  2015
# 252  0.782360         0.647380  0.276680   0.070470    0.235070  2016
# 406  1.207893         0.644948  0.325906   0.060278    0.253761  2017
# 558  1.239000         0.691000  0.394000   0.052000    0.173000  2018

# %%
df[df['country'] == 'North Macedonia']
# Out:
#              country region  rank  score  gdp_per_capita  family  \
# 709  North Macedonia    NaN    84  5.274           0.983   1.294
#
#      life_expectancy  freedom  gov_trust  generosity  year
# 709            0.838    0.345      0.034       0.185  2019

# %%
# we can set north macedonia to macedonia
df.loc[709, 'country'] = 'Macedonia'
df.loc[709, 'region'] = 'Central and Eastern Europe'

# %%
df.loc[745,'region'] = 'Middle East and Northern Africa'

# %%
df[df['country'] == 'North Cyprus']
# Out:
#           country          region  rank  score  gdp_per_capita    family  \
# 65   North Cyprus  Western Europe    66  5.695        1.208060  1.070080
# 219  North Cyprus  Western Europe    62  5.771        1.311410  0.818260
# 375  North Cyprus  Western Europe    61  5.810        1.346911  1.186303
#
#      life_expectancy   freedom  gov_trust  generosity  year
# 65          0.923560  0.490270   0.142800    0.261690  2015
# 219         0.841420  0.435960   0.165780    0.263220  2016
# 375         0.834647  0.471204   0.155353    0.266846  2017

# %%
df[df['country'] == 'Northern Cyprus']
# Out:
#              country region  rank  score  gdp_per_capita  family  \
# 527  Northern Cyprus    NaN    58  5.835           1.229   1.211
# 689  Northern Cyprus    NaN    64  5.718           1.263   1.252
#
#      life_expectancy  freedom  gov_trust  generosity  year
# 527            0.909    0.495      0.154       0.179  2018
# 689            1.042    0.417      0.162       0.191  2019

# %%
# Manually input western europe
df.loc[[527,689], 'country'] = 'North Cyprus'
df.loc[[527,689], 'region'] = 'Western Europe'

# %%
df.isnull().any(1).sum()
# Out:
# 0

# %% [markdown]
# # Finally, our data is clean

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# #### country

# %%
year_grouped = df.groupby('country')['year'].count()
year_grouped.value_counts()
# Out:
# 5    146
# 4      9
# 1      6
# 3      2
# 2      2
# Name: year, dtype: int64

# %%
plt.style.use('ggplot')
plt.figure(figsize = (12,8))
year_grouped[year_grouped < 4].plot.barh()
plt.title('Countries with less than 4 entries in the data')
plt.xlabel('Count')
plt.locator_params(axis='x', nbins=4)

# %%
df[df['country'].str.contains('Somaliland')]
# Out:
#                country              region  rank  score  gdp_per_capita  \
# 90   Somaliland region  Sub-Saharan Africa    91  5.057         0.18847
# 254  Somaliland Region  Sub-Saharan Africa    97  5.057         0.25558
#
#       family  life_expectancy  freedom  gov_trust  generosity  year
# 90   0.95152          0.43873  0.46582    0.39928     0.50318  2015
# 254  0.75862          0.33108  0.39130    0.36794     0.51479  2016

# %%
df.loc[90,'country'] = 'Somaliland Region'

# %% [markdown]
# #### region

# %%
df['region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
plt.style.use('ggplot')
plt.figure(figsize = (10,6))
df['region'].value_counts().sort_values().plot.barh()
plt.title('Number of countries by region')
plt.xlabel('Counts')
# Out:
# Text(0.5, 0, 'Counts')

# %%
df.loc[df['region'] == 'North America', 'country'].unique()
# Out:
# array(['Canada', 'United States'], dtype=object)

# %% [markdown]
# #### Score

# %%
df.describe().loc[:,'score']
# Out:
# count    782.000000
# mean       5.379018
# std        1.127456
# min        2.693000
# 25%        4.509750
# 50%        5.322000
# 75%        6.189500
# max        7.769000
# Name: score, dtype: float64

# %%
plt.figure(figsize = (10,6))
sns.kdeplot(df['score'])
plt.hist(df['score'], density = True, color = 'orange')
plt.ylabel('Prob')
# Out:
# Text(0, 0.5, 'Prob')

# %%
df.describe().loc[:,'gdp_per_capita']
# Out:
# count    782.000000
# mean       0.916047
# std        0.407340
# min        0.000000
# 25%        0.606500
# 50%        0.982205
# 75%        1.236187
# max        2.096000
# Name: gdp_per_capita, dtype: float64

# %%
plt.figure(figsize = (10,6))
sns.kdeplot(df['gdp_per_capita'])
plt.hist(df['gdp_per_capita'], density = True, color = 'orange')
plt.ylabel('Prob')
print(df['gdp_per_capita'].skew())
# Out:
# -0.3185805094075457

# %% [markdown]
# This data is skewed to the left

# %% [markdown]
# ### checking correlation

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(), annot = True, cmap = 'RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# score is highly correlated to the gdp per capita, family, life expectancy, freedom, and government trust.
# life expectancy is highly correlated to gdp and family
# government trust and freedom are correlated

# %% [markdown]
# #### Top 10 countries per year

# %%
def top(df, col = 'rank', n = 10):
    return df.sort_values(by = col)[:n]

# %%
top10 = df.groupby('year', as_index = False).apply(top, n = 10)
top10.head()
# Out:
#          country          region  rank  score  gdp_per_capita   family  \
# 0 0  Switzerland  Western Europe     1  7.587         1.39651  1.34951
#   1      Iceland  Western Europe     2  7.561         1.30232  1.40223
#   2      Denmark  Western Europe     3  7.527         1.32548  1.36058
#   3       Norway  Western Europe     4  7.522         1.45900  1.33095
#   4       Canada   North America     5  7.427         1.32629  1.32261
#
#      life_expectancy  freedom  gov_trust  generosity  year
# 0 0          0.94143  0.66557    0.41978     0.29678  2015
#   1          0.94784  0.62877    0.14145     0.43630  2015
#   2          0.87464  0.64938    0.48357     0.34139  2015
#   3          0.88521  0.66973    0.36503     0.34699  2015
#   4          0.90563  0.63297    0.32957     0.45811  2015

# %%
fig = plt.figure(figsize = (15,12))
ax = fig.add_subplot()
ax = sns.lineplot(data = top10, y = 'rank', x = 'year', hue = 'country')
ax.set_yticklabels(['','1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th',''])
plt.locator_params(axis='y', nbins=11)
plt.locator_params(axis='x', nbins=6)
plt.legend(ncol = 3, frameon = False, fontsize = 8)
ax.set_ylim(11, 0)
plt.title('Top 10 countries per year')
# Out:
# <ipython-input-294-2d7fd02cc19e>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['','1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th',''])
# Text(0.5, 1.0, 'Top 10 countries per year')

# %%
denmark = df[df['country'] == 'Denmark']
denmark
# Out:
#      country          region  rank  score  gdp_per_capita    family  \
# 2    Denmark  Western Europe     3  7.527        1.325480  1.360580
# 158  Denmark  Western Europe     1  7.526        1.441780  1.163740
# 316  Denmark  Western Europe     2  7.522        1.482383  1.551122
# 472  Denmark  Western Europe     3  7.555        1.351000  1.590000
# 627  Denmark  Western Europe     2  7.600        1.383000  1.573000
#
#      life_expectancy   freedom  gov_trust  generosity  year
# 2           0.874640  0.649380    0.48357     0.34139  2015
# 158         0.795040  0.579410    0.44453     0.36171  2016
# 316         0.792566  0.626007    0.40077     0.35528  2017
# 472         0.868000  0.683000    0.40800     0.28400  2018
# 627         0.996000  0.592000    0.41000     0.25200  2019

# %% [markdown]
# compare denmark to average

# %%
denmark_details = denmark.describe().loc['mean','score':'generosity']
denmark_details.name = 'Denmark'

# %%
idx = pd.IndexSlice
average_by_region = df.groupby('region').describe().loc[:,idx['score':'generosity','mean']]
average_by_region.columns = average_by_region.columns.swaplevel().droplevel()
denmark_compared = average_by_region.T.merge(denmark_details, right_index = True, left_index = True).T
denmark_compared
# Out:
#                                     score  gdp_per_capita    family  \
# Australia and New Zealand        7.294600        1.356197  1.424368
# Central and Eastern Europe       5.427807        1.018488  1.172368
# Eastern Asia                     5.651567        1.237695  1.199232
# Latin America and Caribbean      6.023811        0.941661  1.187033
# Middle East and Northern Africa  5.328742        1.094441  0.992905
# North America                    7.174700        1.422037  1.357991
# Southeastern Asia                5.335227        0.893340  1.093673
# Southern Asia                    4.580657        0.638813  0.803835
# Sub-Saharan Africa               4.188482        0.448843  0.845211
# Western Europe                   6.740590        1.370289  1.336807
# Denmark                          7.546000        1.396729  1.447688
#
#                                  life_expectancy   freedom  gov_trust  \
# Australia and New Zealand               0.903074  0.611413   0.357294
# Central and Eastern Europe              0.696532  0.352233   0.075680
# Eastern Asia                            0.862612  0.418185   0.117992
# Latin America and Caribbean             0.676074  0.464330   0.092432
# Middle East and Northern Africa         0.663116  0.349023   0.146625
# North America                           0.861086  0.558918   0.223345
# Southeastern Asia                       0.635452  0.543723   0.136140
# Southern Asia                           0.513089  0.392867   0.100357
# Sub-Saharan Africa                      0.283140  0.353492   0.105672
# Western Europe                          0.894239  0.515709   0.222535
# Denmark                                 0.865249  0.625959   0.429374
#
#                                  generosity
# Australia and New Zealand          0.424441
# Central and Eastern Europe         0.157000
# Eastern Asia                       0.199801
# Latin America and Caribbean        0.185378
# Middle East and Northern Africa    0.179206
# North America                      0.372339
# Southeastern Asia                  0.384195
# Southern Asia                      0.300888
# Sub-Saharan Africa                 0.207277
# Western Europe                     0.270331
# Denmark                            0.318876

# %%
fig, ax = plt.subplots(figsize = (15,15))
denmark_compared.drop(['family','gov_trust','generosity'],
                     axis = 1).sort_values(by = ['score'], 
                                           ascending = False).T.plot.bar(ax = ax, width = .8)
plt.title('Denmark compared to other regions')
ax.set_xticklabels(['Score','GDP','Life Expectancy','Freedom'], rotation = 60);

# %% [markdown]
# The happiness indices of Denmark is high. Region with the lowest indices are africa and and asia

# %% [markdown]
# ##### most changed countries

# %%
rank = df.loc[:,['country','rank','year','score']]
rank.head()
# Out:
#        country  rank  year  score
# 0  Switzerland     1  2015  7.587
# 1      Iceland     2  2015  7.561
# 2      Denmark     3  2015  7.527
# 3       Norway     4  2015  7.522
# 4       Canada     5  2015  7.427

# %%
rankgroup = rank.groupby(['country','year'])['rank'].mean().unstack()
rankgroup['rank diff'] = rankgroup.max(1) - rankgroup.min(1)

# %%
top10changes = rankgroup.sort_values(by = 'rank diff', ascending = False).head(10)

# %%
country_top10_change = top10changes.drop('rank diff', 1).stack().reset_index().rename(columns = {0:'rank'})

# %%
plt.figure(figsize = (15,10))
sns.lineplot(data = country_top10_change, x = 'year', y = 'rank', hue = 'country', palette = sns.color_palette("hls", 10))
plt.legend(ncol = 2)
plt.locator_params(axis='x', nbins=6)
plt.gca().invert_yaxis()
plt.title('Top 10 countries with the highest change in rank');

# %% [markdown]
# Venezuela, Algeria, Zambia dropped their rank from 2015 to 2019 whereas Ivory Coast, Benin, and Honduras increased ranking

# %% [markdown]
# ##### top countries by region

# %%
def top_score(df, col = 'score', n = 5, ascending = True):
    return df.sort_values(by = col)[-n:]

# %%
top_byregion = df.groupby(['country','region'], as_index = False)['score'].mean().groupby('region').apply(top_score, n = 1).reset_index(drop = True)
fig = plt.figure(figsize = (12,10))
ax = fig.add_subplot()
top_byregion.set_index(['region','country']).plot.bar(ax = ax)

#make 2 rows for xticklabels 
indexes = list(top_byregion.set_index(['region','country']).index.values)
multilist = []
for i in indexes:
    multilist.append(list(i))
region_country = []
for i in multilist:
    region_country.append('\n'.join(i))
ax.set_xticklabels(region_country);
plt.legend('')
plt.title('Happiest Country by Region')
# Out:
# Text(0.5, 1.0, 'Happiest Country by Region')

# %% [markdown]
# The difference between the happiest country by region is minimal. Pakistan in Southern Asia is the least happiest among the top happiest countries

# %%
EuMe = df[(df['region'] == 'Western Europe') | df['region'].str.contains('Middle East')]
Top5EuMe = EuMe.groupby(['country','region'], as_index = False)['score'].mean().groupby('region').apply(top_score).reset_index(drop = True)

#plotting
fig = plt.figure(figsize = (12,10))
ax = fig.add_subplot()
sns.barplot(x = 'country', y ='score', data = Top5EuMe, hue = 'region', ax = ax)
plt.title('Top 5 highest scores in Regions WE and ME-NA')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');

# %% [markdown]
# On average, Countries on Western Europe have relatively close happiness scores. In middle east and north africa, Israel has the happiest population

# %%
def bottom(df, col = 'score', n = 5, ascending = True):
    return df.sort_values(by = col)[:n]

# %%
SubAfr_EastAsia = df[(df['region'] == 'Southern Asia') | df['region'].str.contains('Sub-')]
Bottom5 =  SubAfr_EastAsia.groupby(['country','region'], as_index = False)['score'].mean().groupby('region').apply(bottom, ascending = False, n = 5).reset_index(drop = True)

#plotting
fig = plt.figure(figsize = (12,10))
ax = fig.add_subplot()
sns.barplot(x = 'country', y ='score', data = Bottom5, hue = 'region', ax = ax)
plt.title('Bottom 5 countries in Southern Asia and Sub-Suharan Africa')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');

# %% [markdown]
# #### Mean and std of happiness score by region

# %%
region_score = df.groupby(['region','year'], as_index = False).agg({'score':['mean',np.std]}).rename(columns = {'mean':'mean_score', 'std':'std_score'})
region_score.columns = region_score.columns.droplevel(1)
region_score.columns = ['region','year','mean_score','std_score']

# %%
c = ['red','blue','green','cyan','magenta','yellow','black','brown','gray','pink']

# %%
def year_plot(df, title, col = ['region'], ylim = [3.5,7]):
    fig = plt.figure(figsize = (12,10))
    ax = plt.subplot()
    for i in df.groupby(col):
        plt.plot(i[1].year, i[1].mean_score, label = i[0], marker = 'o')
    plt.legend(ncol = 2, fontsize = 8, columnspacing = .5)
    plt.ylim(ylim)
    plt.title(title)
    plt.locator_params(axis='x', nbins=6)
    
year_plot(region_score, title = 'Happiness Score by region')

# %% [markdown]
# The trend of happiness score by region shows that western Europe Scores have been increasing since 2015 whereas the region Southeastern Asia and Middle East have been decreasing since 2017

# %% [markdown]
# ### Top 10 by hapiness index

# %%
def topN(df, col,  title = 'Please insert title', n=10):
    plt.figure(figsize = (10,8))
    df.groupby('country')[col].mean().sort_values(ascending = False)[:n].plot(kind = 'bar', title = title)

# %%
topN(df, col = 'generosity', title = 'Top10 most generous country')

# %% [markdown]
# Asians are the most generous people

# %%
topN(df, col = 'freedom', title = 'Top10 most free country')

# %%
topN(df, col = 'gov_trust', n = 10, title = 'Top 10 countries with highest trust on its government')

# %%
topN(df, col = 'family', n = 10, title = 'Top 10 countries with highest family/social support')

# %% [markdown]
# Denmark is included in top 3 in governmetn trust and social support. Iceland is the top1. The difference is minimal

# %%
topN(df, col = 'gdp_per_capita', n = 10, title = 'Top 10 countries with highest gdp_per_capita')

# %% [markdown]
# Qatar and UAE has the highest GDP per capita. Let's try to locate the rank of the countries with top10 highest GDP

# %%
Top10GDP_rank = df.groupby('country')['gdp_per_capita','rank'].mean().nlargest(10, 'gdp_per_capita').loc[:,'rank']
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot()
ax.plot(Top10GDP_rank.index,Top10GDP_rank, linestyle = '', marker = 'o')
ax.set_xticklabels(Top10GDP_rank.index, rotation = 60)
ax.set_ylim(0, 80)
for country, rank in zip(Top10GDP_rank.index,Top10GDP_rank):
    ax.annotate(rank,(country, rank + 3))
# Out:
# <ipython-input-318-5c1af970a042>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Top10GDP_rank = df.groupby('country')['gdp_per_capita','rank'].mean().nlargest(10, 'gdp_per_capita').loc[:,'rank']
# <ipython-input-318-5c1af970a042>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Top10GDP_rank.index, rotation = 60)

# %% [markdown]
# #### NIGERIA

# %%
ph = df[df['country'] == 'Nigeria']
ph
# Out:
#      country              region  rank  score  gdp_per_capita   family  \
# 77   Nigeria  Sub-Saharan Africa    78  5.268        0.654350  0.90432
# 260  Nigeria  Sub-Saharan Africa   103  4.875        0.752160  0.64498
# 409  Nigeria  Sub-Saharan Africa    95  5.074        0.783756  1.21577
# 560  Nigeria  Sub-Saharan Africa    91  5.155        0.689000  1.17200
# 710  Nigeria  Sub-Saharan Africa    85  5.265        0.696000  1.11100
#
#      life_expectancy   freedom  gov_trust  generosity  year
# 77          0.160070  0.343340   0.040300    0.272330  2015
# 260         0.051080  0.278540   0.030500    0.232190  2016
# 409         0.056916  0.394953   0.026122    0.230947  2017
# 560         0.048000  0.462000   0.032000    0.201000  2018
# 710         0.245000  0.426000   0.041000    0.215000  2019

# %% [markdown]
# Compare Nigeria to average

# %%
average = df.describe().loc['mean','score':'generosity']
average.name = 'Global Average'

# %%
ph_mean = ph.describe().loc['mean','score':'generosity']
ph_mean.name = 'Nigeria'

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot()
pd.DataFrame([average, ph_mean]).T.plot.barh(ax = ax)
ax.set_ylabel('Indices')
ax.set_xlabel('Value')
ax.set_title('Nigeria happiness indices compared to global average')
# Out:
# Text(0.5, 1.0, 'Nigeria happiness indices compared to global average')

# %% [markdown]
# We can fairly say the philippine is near average. It has higher scores on family and freedom but has low life expectanc

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot()
ax.plot(ph['year'], ph['rank'])
ax.locator_params(axis='x', nbins=6)
ax.invert_yaxis()
ax.set_ylabel('Rank')
ax.set_xlabel('year')
ax.set_title('Nigeria ranking on happiness (2015 - 2019)')

for year, rank in zip(ph['year'],ph['rank']):
    ax.annotate(rank,(year, rank + 1))

# %% [markdown]
# Happiness score has been improving in Nigeria since 2016

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot()
ph.set_index('year').loc[:,'gdp_per_capita':'generosity'].plot(kind = 'line', ax = ax, marker = 'o')
plt.legend(ncol = 2)
ax.locator_params(axis='x', nbins=6)
ax.set_ylim(0, 1.4)
plt.title('Happiness index in the Nigeria')
# Out:
# Text(0.5, 1.0, 'Happiness index in the Nigeria')

# %% [markdown]
# Some parameters like Gov_trust and Generosity were fairly stable from 2015 to 2019. Life_expectancy have been slightly increasing since 2016

# %% [markdown]
# ##### ph ranks in Sub-Saharan Africa countries

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()
df[df['region'] == 'Sub-Saharan Africa'].groupby('country').agg('mean').drop(['rank','year'],1).sort_values(by = 'score', ascending = False).T.plot(kind = 'bar', ax = ax, width = .8)
ax.set_title('Nigeria compared to other regions')
ax.set_ylabel('Value')
ax.set_xlabel('Variables')
plt.legend(ncol = 3)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');

# %% [markdown]
# Nigeria is the colour blue. We ranked one of the lowest in terms of gov_trust. Our life expectancy is among the lowest. Rawanda has very high value in government trust compared to other Sub-Saharan Africa countries. We can see here that Mauritius is the best Sub-Saharan Africa country followed by Nigeria

# %% [markdown]
# # Which country is the happiest in the world

# %% [markdown]
# The happiest country in the world is DENMARK

# %% [markdown]
# # What are the most important contributing factors to a nation’s happiness?

# %% [markdown]
# The three most contributing factors are gdp_per_capita, family, life_expectancy

# %% [markdown]
# # Is overall happiness increasing or decreasing?

# %% [markdown]
# world happiness is decreasing

# %% [markdown]
# Other contributing factors include: Freedom and Trust(Government Corruption)

# %% [markdown]
# Perception to corruption is highly and postively correlated with the happiness score. Although this should not be a  factor.
# High perception of corruption will not cause people in country become happy for sure. Distribution of Perceptions of corruption
# rightly skewed that means very less number of the country has high perceptions of corruption. That means most of the country
# has corruption problems.
#
# Lesotho and Swaziland have the lowest life expectancy and this can be due to Poor liviv=ng conditions, Diseases, natural disasters and inadequate healthy food
#
# I observe here that Singapore has the highest life expectancy score. This indicates satisfaction of the people with the life expectancy of their country.
# This can be due to Proper healthcare facilities, Better living conditions
#
# Generosity has a fragile linear relationship with the Happiness Score. Generosity scores are calculated based on the countries
# which give the most to nonprofits around the world. Countries that are not generous that does not mean they are not happy.
